# %% [markdown]
# # So you want to make a killer app?
# # Well then what kind of app should it be?  Which category should it be in?  Should you settle for throwing together a free app?  Should you take time making a good paid app, or will the price scare people away?
# ## In this project, we will analyze data from the Google Play App Store.
# ## We will use use Pandas to make dataframes from two csv files:
# ## 1. app data
# ## 2. user review data
# ## Thereafter we will determine what questions we can answer using the data we have.
# ## We will determine what limitations our data has based on what we want to ask and what data we have, and how to work around these limitations via data-cleansing.
# ## Finally, we will use Matplotlib to produce visuals to display our findings.

# %% [markdown]
# ## Visualization Ideas:

# %% [markdown]
# Compare something about each category on multiple line graphs / scatter plots
# https://python-graph-gallery.com/125-small-multiples-for-line-chart/
# https://python-graph-gallery.com/199-matplotlib-style-sheets/
# https://python-graph-gallery.com/392-use-faceting-for-radar-chart/
# https://python-graph-gallery.com/111-custom-correlogram/
# https://python-graph-gallery.com/110-basic-correlation-matrix-with-seaborn/
# https://python-graph-gallery.com/242-area-chart-and-faceting/
# http://python-graph-gallery.com/242-area-chart-and-faceting/

# %% [markdown]
# 3-Dimensional graphs
# https://python-graph-gallery.com/372-3d-pca-result/
# https://python-graph-gallery.com/370-3d-scatterplot/
# https://python-graph-gallery.com/371-surface-plot/
# https://python-graph-gallery.com/342-animation-on-3d-plot/
# https://python-graph-gallery.com/312-add-markers-on-folium-map/

# %% [markdown]
# Animated Graphs
# https://python-graph-gallery.com/341-python-gapminder-animation/ - Change per category, change per number of times downloaded bins? Change per size? Change per price?
# https://python-graph-gallery.com/340-scatterplot-animation/

# %% [markdown]
# Annotate Graph
# https://python-graph-gallery.com/193-annotate-matplotlib-chart/

# %% [markdown]
# Multiple bars bar chart
# https://python-graph-gallery.com/11-grouped-barplot/ - Comparing all apps vs only ones with rating?

# %% [markdown]
# Stacked barcharts- comparing all apps vs only ones with rating?
# https://python-graph-gallery.com/13-percent-stacked-barplot/
# https://python-graph-gallery.com/12-stacked-barplot-with-matplotlib/
# https://python-graph-gallery.com/11-grouped-barplot/
# https://python-graph-gallery.com/10-barplot-with-number-of-observation/

# %% [markdown]
# Chord diagram
# https://python-graph-gallery.com/231-chord-diagram-with-bokeh/

# %% [markdown]
# Word clouds- use with reviews dataframe?
# http://python-graph-gallery.com/wordcloud/
# https://python-graph-gallery.com/260-basic-wordcloud/
# https://python-graph-gallery.com/261-custom-python-wordcloud/
# https://python-graph-gallery.com/200-basic-treemap-with-python/
# https://python-graph-gallery.com/201-control-the-color-of-treemap/

# %% [markdown]
# Multiple lines same chart
# https://python-graph-gallery.com/122-multiple-lines-chart/

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
from wordcloud import WordCloud

# %%
app_data = pd.read_csv("Data/google-play-store-apps/googleplaystore.csv")
review_data = pd.read_csv("Data/google-play-store-apps/googleplaystore_user_reviews.csv")

# %%
app_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
app_data[(app_data["Category"] == "SPORTS") & (app_data["Rating"] >= 4.5)]
# Out:
#                                                      App Category  Rating  \
# 2965                         Onefootball - Soccer Scores   SPORTS     4.7
# 2966                         Cristiano Ronaldo Wallpaper   SPORTS     4.6
# 2970                                Football Live Scores   SPORTS     4.5
# 2971                           Pro 2018 - Series A and B   SPORTS     4.6
# 2972                        BeSoccer - Soccer Live Score   SPORTS     4.5
# 10280      10                 14M         500+  Free      0         Everyone
# 10281     688  Varies with device      10,000+  Free      0         Everyone
# 10286     169                 19M      10,000+  Free      0         Everyone
# 10527    1420                 20M      10,000+  Free      0         Everyone
# 10552    1211                 15M      10,000+  Free      0         Everyone
# 10564      36                2.6M         100+  Free      0         Everyone
# 10570      60                 24M       1,000+  Paid  $1.99         Everyone
# 10604    1566                 26M      50,000+  Free      0         Everyone
#
#        Genres       Last Updated         Current Ver         Android Ver
# 2965   Sports     August 1, 2018          10.8.1.330          4.4 and up
# 2966   Sports      July 17, 2018                 2.1          4.1 and up
# 2970   Sports      July 31, 2018              1004.0          4.0 and up
# 2971   Sports     August 3, 2018            2.24.2.0        4.0.3 and up
# 2972   Sports      July 18, 2018  Varies with device  Varies with device
# 2974   Sports      July 31, 2018  Varies with device  Varies with device
# 2982   Sports     August 3, 2018               3.0.5          4.1 and up
# 2987   Sports      June 21, 2018             2.9.9go          4.1 and up
# 2993   Sports       July 1, 2018              1.0.16          2.3 and up
# 2994   Sports       May 23, 2018                 5.5          4.1 and up
# 2997   Sports      July 24, 2018               6.4.8        4.0.3 and up
# 2998   Sports      July 17, 2018                 2.6          4.1 and up
# 3000   Sports      July 31, 2018             1.2.677          4.4 and up
# 3025   Sports     August 1, 2018              5.10.5          4.1 and up
# 3029   Sports        May 3, 2018  Varies with device  Varies with device
# 3030   Sports      July 30, 2018  Varies with device          4.4 and up
# 3035   Sports      July 28, 2018  Varies with device  Varies with device
# 3041   Sports     August 6, 2018              2.46.1          5.0 and up
# 3043   Sports      July 24, 2018            3.21.324          4.4 and up
# 3051   Sports       June 5, 2018                 3.9        4.0.3 and up
# 3053   Sports       May 18, 2018  Varies with device  Varies with device
# 3057   Sports      July 18, 2018              2.28.1          4.1 and up
# 3058   Sports     August 1, 2018               7.8.0          5.1 and up
# 3065   Sports       July 5, 2018               1.2.0          4.2 and up
# 3066   Sports     August 1, 2018               7.8.0          5.1 and up
# 3069   Sports      July 31, 2018  Varies with device  Varies with device
# 3070   Sports       July 7, 2018  Varies with device  Varies with device
# 3076   Sports      April 3, 2018              6.9.12          2.3 and up
# 3078   Sports    August 23, 2016  Varies with device  Varies with device
# 3083   Sports      July 29, 2018               5.5.9          4.1 and up
# ...       ...                ...                 ...                 ...
# 9564   Sports     August 1, 2018               6.5.3          5.0 and up
# 9613   Sports     August 2, 2018               3.9.1          5.0 and up
# 9618   Sports     August 1, 2018              5.10.5          4.1 and up
# 10166  Sports      July 23, 2018               1.6.0        4.0.3 and up
# 10238  Sports  November 13, 2017               2.6.0          4.0 and up
# 10241  Sports       May 17, 2018       2.1.0.0.15734          4.1 and up
# 10242  Sports     August 6, 2018              2.22.0          4.2 and up
# 10245  Sports     August 4, 2018                 4.0          4.1 and up
# 10246  Sports     August 1, 2018              1.3.11          4.1 and up
# 10252  Sports      July 20, 2018              1.13.0          4.4 and up
# 10254  Sports      June 19, 2018               2.6.0        4.0.3 and up
# 10258  Sports     August 1, 2018            2018.8.1          4.4 and up
# 10261  Sports      June 26, 2018               3.0.0          4.1 and up
# 10262  Sports     August 1, 2018            2018.8.1          4.4 and up
# 10264  Sports   January 18, 2018               2.0.2  Varies with device
# 10268  Sports       May 29, 2018           2018.5.25          4.4 and up
# 10269  Sports      July 31, 2018             1.2.677          4.4 and up
# 10271  Sports     August 7, 2018             4.0.4-R          5.0 and up
# 10272  Sports     April 18, 2018              3.0.10          4.1 and up
# 10273  Sports     August 6, 2016              060816          4.2 and up
# 10278  Sports      July 26, 2018              2.0.20          5.0 and up
# 10279  Sports     August 2, 2018               23.17          4.1 and up
# 10280  Sports      March 9, 2018          2.0.833.18        4.0.3 and up
# 10281  Sports    January 7, 2015  Varies with device  Varies with device
# 10286  Sports      July 27, 2018          2.0.855.33        4.0.3 and up
# 10527  Sports      July 12, 2018               2.5.0          4.2 and up
# 10552  Sports   January 22, 2018               1.0.1          4.4 and up
# 10564  Sports  February 11, 2017                 1.1          4.0 and up
# 10570  Sports      March 7, 2014                1.03          2.2 and up
# 10604  Sports      July 13, 2018              9.19.2          4.1 and up
#
# [93 rows x 13 columns]

# %%
print(app_data.shape)
app_data.count()
# Out:
# (10841, 13)
# App               10841
# Category          10841
# Rating             9367
# Reviews           10841
# Size              10841
# Installs          10841
# Type              10840
# Price             10841
# Content Rating    10840
# Genres            10841
# Last Updated      10841
# Current Ver       10833
# Android Ver       10838
# dtype: int64

# %%
review_data.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
print(review_data.shape)
review_data.count()
# Out:
# (64295, 5)
# App                       64295
# Translated_Review         37427
# Sentiment                 37432
# Sentiment_Polarity        37432
# Sentiment_Subjectivity    37432
# dtype: int64

# %%
categories = app_data["Category"].unique()
average_rating_by_category = app_data.groupby("Category")["Rating"].mean()

# %%
plt.subplots(figsize=(10,10))
sns.barplot(average_rating_by_category, categories, orient="h")
plt.show()

# %% [markdown]
# ### Interesting, what is that 1.9 category?

# %%
app_data[app_data["Category"] == "1.9"]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
categories_19_dropped = app_data[app_data["Category"] != "1.9"]["Category"].unique()
average_rating_by_category_19_dropped = app_data[app_data["Category"] != "1.9"].groupby("Category")["Rating"].mean()

# %%
plt.subplots(figsize=(10,10))
sns.barplot(average_rating_by_category_19_dropped, categories_19_dropped, orient="h")
plt.show()

# %% [markdown]
# ### Right now it's still difficult to tell the difference between the average rating.  We will also adjust our axes to more accurately show the range of values.

# %%
average_rating_by_category_19_dropped_sorted = average_rating_by_category_19_dropped.sort_values()
categories_19_dropped_sorted_by_average_rating = average_rating_by_category_19_dropped_sorted.index

# %%
average_rating_by_category_19_dropped_sorted.head(1)
# Out:
# Category
# DATING    3.970769
# Name: Rating, dtype: float64

# %%
plt.subplots(figsize=(10,10))
bar_chart_average_rating_by_category = sns.barplot(average_rating_by_category_19_dropped_sorted, categories_19_dropped_sorted_by_average_rating, orient="h")
plt.title("Average Rating by Category")
bar_chart_average_rating_by_category.set(xlim=(3.9,4.5))
plt.grid()
plt.show()

# %%
review_data.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
review_data[review_data["Sentiment"] == "Negative"]
# Out:
#                                     App  \
# 32                10 Best Foods for You
# 43                10 Best Foods for You
# 68                10 Best Foods for You
# 85                10 Best Foods for You
# 95                10 Best Foods for You
# 132               10 Best Foods for You
# 143               10 Best Foods for You
# 168               10 Best Foods for You
# 185               10 Best Foods for You
# 195               10 Best Foods for You
# 206    104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 240                                11st
# 245                                11st
# 246                                11st
# 253                                11st
# 255                                11st
# 274                                11st
# 276                                11st
# 281          1800 Contacts - Lens Store
# 300          1800 Contacts - Lens Store
# 309          1800 Contacts - Lens Store
# 321          1800 Contacts - Lens Store
# 340          1800 Contacts - Lens Store
# 349          1800 Contacts - Lens Store
# 360     1LINE – One Line with One Touch
# 366     1LINE – One Line with One Touch
# 367     1LINE – One Line with One Touch
# 369     1LINE – One Line with One Touch
# 370     1LINE – One Line with One Touch
# 372     1LINE – One Line with One Touch
# ...                                 ...
# 64123                           Hotstar
# 64124                           Hotstar
# 64127                           Hotstar
# 64131                           Hotstar
# 64132                           Hotstar
# 64134                           Hotstar
# 64135                           Hotstar
# 64137                           Hotstar
# 64141                           Hotstar
# 64143                           Hotstar
# 64145                           Hotstar
# 64147                           Hotstar
# 64151                           Hotstar
# 64155                           Hotstar
# 64157    Hotwire Hotel & Car Rental App
# 64165    Hotwire Hotel & Car Rental App
# 64173    Hotwire Hotel & Car Rental App
# 64174    Hotwire Hotel & Car Rental App
# 64177    Hotwire Hotel & Car Rental App
# 64185    Hotwire Hotel & Car Rental App
# 64196    Housing-Real Estate & Property
# 64197    Housing-Real Estate & Property
# 64199    Housing-Real Estate & Property
# 64201    Housing-Real Estate & Property
# 64213    Housing-Real Estate & Property
# 64215    Housing-Real Estate & Property
# 64216    Housing-Real Estate & Property
# 64220    Housing-Real Estate & Property
# 64226    Housing-Real Estate & Property
# 64230    Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 32                    No recipe book Unable recipe book.  Negative
# 43     Waste time It needs internet time n ask calls ...  Negative
# 68                               Faltu plz waste ur time  Negative
# 85                                     Crap Doesn't work  Negative
# 95     Boring. I thought actually just texts that's i...  Negative
# 132                   No recipe book Unable recipe book.  Negative
# 143    Waste time It needs internet time n ask calls ...  Negative
# 168                              Faltu plz waste ur time  Negative
# 185                                    Crap Doesn't work  Negative
# 195    Boring. I thought actually just texts that's i...  Negative
# 206                  Not bad, price little bit expensive  Negative
# 240                             Horrible ID verification  Negative
# 245                       There is nothing missing ~ !!!  Negative
# 246    Refund takes long.. 3 days still received mone...  Negative
# 253    I am trying to update every time but I do not ...  Negative
# 255                  Icon name is strange after updating  Negative
# 274    It has been slowed down since the last update....  Negative
# 276    If a network error occurs, the app should save...  Negative
# 281    It's expensive I expected (I thought I'd savin...  Negative
# 300    Does need do. No sense giving anything less 5 ...  Negative
# 309    First time app, always used doctors office sta...  Negative
# 321    It's expensive I expected (I thought I'd savin...  Negative
# 340    Does need do. No sense giving anything less 5 ...  Negative
# 349    First time app, always used doctors office sta...  Negative
# 360    gets 1* there's ad every single level restart,...  Negative
# 366                                   amaze i'm addicted  Negative
# 367                                          I like game  Negative
# 369                                          I play game  Negative
# 370                                  It's toooo gud game  Negative
# 372                                       Mind uses game  Negative
# ...                                                  ...       ...
# 64123  A lot bugs. Doesnt show recent menu picure pic...  Negative
# 64124  Even trying several times, answers taken Kanna...  Negative
# 64127  U people gave 1000 ads Kannadada kotyadipati p...  Negative
# 64131  Hey developer.. Idk thinking.. ridiculous sayi...  Negative
# 64132  Fckng app. Slow loading many ads movies. Old m...  Negative
# 64134  Hey Novi Digital Team need login facebook ofvt...  Negative
# 64135  The annoying current update...because press ho...  Negative
# 64137  In new update play ಕನ್ನಡದ ಕೋಟ್ಯಧಿಪತಿ (Kannadad...  Negative
# 64141  It's painful watch Kannadada kotyadhipathi r p...  Negative
# 64143  Very worst reality big boss 2 tamil show organ...  Negative
# 64145  After recent update audio end closed. I even r...  Negative
# 64147  Many times disappointing playing sabse smart k...  Negative
# 64151  Stopping constantly! Adverts long n option ski...  Negative
# 64155  Very bad I playing Kannada dha kotyadhipathi I...  Negative
# 64157  The worthless. It allow see information would ...  Negative
# 64165  Scammers!!! give refunds even made mistake. ST...  Negative
# 64173  Buggy hell. Trying get hotel tonight house mes...  Negative
# 64174  This company worst. I used years ok. Now must ...  Negative
# 64177                     Total scam worst ever! Thieves  Negative
# 64185  I hate gives notifications can't disabled. Thi...  Negative
# 64196  Incorrect listings. The agents show property d...  Negative
# 64197  Pathetic app.All posted leads owner either old...  Negative
# 64199  Filters useless I posted owners shows agents a...  Negative
# 64201         Filters work... Searching property useless  Negative
# 64213  This worse ever. They give graphic pictures pr...  Negative
# 64215  Horrible app. I wanted list property get aroun...  Negative
# 64216  Worst app. We get nothing Time waste . They up...  Negative
# 64220  No response support team. After I login, unabl...  Negative
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 32              -0.500000                0.500000
# 43              -0.200000                0.000000
# 68              -0.200000                0.000000
# 85              -0.800000                0.800000
# 95              -0.325000                0.475000
# 132             -0.500000                0.500000
# 143             -0.200000                0.000000
# 168             -0.200000                0.000000
# 185             -0.800000                0.800000
# 195             -0.325000                0.475000
# 206             -0.112500                0.622222
# 240             -1.000000                1.000000
# 245             -0.390625                0.050000
# 246             -0.325000                0.650000
# 253             -0.308333                0.458333
# 255             -0.050000                0.150000
# 274             -0.086806                0.324306
# 276             -0.194444                0.416667
# 281             -0.300000                0.500000
# 300             -0.166667                0.066667
# 309             -0.125000                0.516667
# 321             -0.300000                0.500000
# 340             -0.166667                0.066667
# 349             -0.125000                0.516667
# 360             -0.157143                0.704762
# 366             -0.400000                0.600000
# 367             -0.400000                0.400000
# 369             -0.400000                0.400000
# 370             -0.400000                0.400000
# 372             -0.400000                0.400000
# ...                   ...                     ...
# 64123           -0.425000                0.629167
# 64124           -0.166667                0.100000
# 64127           -0.172727                0.613333
# 64131           -0.166667                0.550000
# 64132           -0.200000                0.400000
# 64134           -0.266667                0.400000
# 64135           -0.200000                0.675000
# 64137           -0.116234                0.414935
# 64141           -0.350000                0.950000
# 64143           -0.555556                0.644444
# 64145           -0.125000                0.375000
# 64147           -0.155102                0.506122
# 64151           -0.039062                0.366667
# 64155           -0.455000                0.483333
# 64157           -0.233333                0.655556
# 64165           -0.875000                0.666667
# 64173           -0.004167                0.270833
# 64174           -0.041667                0.662500
# 64177           -0.500000                0.875000
# 64185           -0.166667                0.600000
# 64196           -0.025000                0.125000
# 64197           -0.362500                0.625000
# 64199           -0.500000                0.200000
# 64201           -0.500000                0.200000
# 64213           -0.081250                0.418750
# 64215           -0.528571                0.717262
# 64216           -0.400000                0.250000
# 64220           -0.377778                0.533333
# 64226           -0.287500                0.250000
# 64230           -0.316667                0.400000
#
# [8271 rows x 5 columns]

# %%
key_words = []

stop_continue = "continue"
while stop_continue == "continue":
    key_word = input("Which keyword would you like to search for? ")
    key_words.append(key_word)
    print(f"Your key words are: {key_words}")
    user_answer = input("\nWould you like to add another keyword?\nType in the word \"stop\" to exit the process.\nOtherwise hit any key to continue. ")
    
    if user_answer == user_answer.lower() == "stop":
        stop_continue = "stop"
        
print(f"Your key words are: {key_words}")
# Out:
# Which keyword would you like to search for? premium
# Your key words are: ['premium']
#
# Would you like to add another keyword?
# Type in the word "stop" to exit the process.
# Otherwise hit any key to continue. stop
# Your key words are: ['premium']

# %%
method_selection = input("This program has two methods for forming word clouds.\nIn both methods the program will search each review for all key words.\nIf the keyword is found in a review at least once, the program will then:\n1. Add only that keyword to a list, then create a word cloud showing the frequency of key words. \n2. Extract every word from that review, to analyze other words that appear with key words.\nPlease enter 1 to use the first method, or 2 to use the second method. ")

try:
    
    if int(method_selection) == 1:
        frequency_words_as_list = []

        for word in key_words:
            for review in review_data["Translated_Review"]:
                if str(word) in str(review):
                    frequency_words_as_list.append(word)

        frequency_words_as_string = ""

        for word in frequency_words_as_list:
            frequency_words_as_string += " " + str(frequency_words_as_list[frequency_words_as_list.index(word)])

        wordcloud = WordCloud(width=1000, height=1000, margin=0).generate(frequency_words_as_string)
        plt.figure()
        plt.imshow(wordcloud, interpolation="bilinear")
        plt.axis("off")
        plt.show()

    elif int(method_selection) == 2:
        review_words = ""

        for word in key_words:
            for review in review_data["Translated_Review"]:
                if word in str(review):
                    review_words += " " + str(review)

        wordcloud = WordCloud(width=1000, height=1000, margin=0).generate(review_words)
        plt.figure()
        plt.imshow(wordcloud, interpolation="bilinear")
        plt.axis("off")
        plt.show()
        
    else:
        print("It appears you gave an invalid input.  Please try again.")

except:
    print("It appears you gave an invalid input.  Please try again.")
# Out:
# This program has two methods for forming word clouds.
# In both methods the program will search each review for all key words.
# If the keyword is found in a review at least once, the program will then:
# 1. Add only that keyword to a list, then create a word cloud showing the frequency of key words.
# 2. Extract every word from that review, to analyze other words that appear with key words.
# Please enter 1 to use the first method, or 2 to use the second method. 2

# %% [markdown]
# # IDEA: Make a chart where you enter a key word and the program searches reviews for that keyword.  If a review finds that keyword, it determines whether the Sentinment column is set to Positive or Negative, and stores the results in two lists.  Thereafter is graphs a double bar chart to compare whether that keyword is more often negative or positive.
#
# # BONUS: Try to find a way to enter more than one keywords and have each keyword plotted a double bar chart with a legend and any other important info for reading the graph.

# %%
# frequency_words_as_list = []

# for word in key_words:
#     for review in review_data["Translated_Review"]:
#         if word in str(review):
#             frequency_words_as_list.append(word)
                
# frequency_words_as_string = ""

# for word in frequency_words_as_list:
#     frequency_words_as_string += " " + str(frequency_words_as_list[frequency_words_as_list.index(word)])
    
# frequency_words_as_string

# wordcloud = WordCloud(width=1000, height=1000, margin=0).generate(frequency_words_as_string)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

# %%
# review_words = ""

# for word in key_words:
#         for review in review_data["Translated_Review"]:
#             if word in str(review):
#                 review_words += " " + str(review)

# wordcloud = WordCloud(width=1000, height=1000, margin=0).generate(review_words)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()
